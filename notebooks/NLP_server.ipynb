# %%
# !pip install fastapi -q
# !pip install pyngrok -q
# !pip install uvicorn -q
# !pip install bitsandbytes -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 103.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 92.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...

# %%
# !pip install -U pynvml
# !pip install -qU vllm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 326.4/326.4 MB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 MB 18.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 119.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.3/343.3 kB 31.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.4/94.4 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 119.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 118.9 MB/s eta 0:00:00
# ...

# %%
# !pip uninstall bitsandbytes -y
# !pip install bitsandbytes --upgrade
# Out:
# Found existing installation: bitsandbytes 0.45.5
# Uninstalling bitsandbytes-0.45.5:
#   Successfully uninstalled bitsandbytes-0.45.5
# ...
#   Using cached bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# ...
# Using cached bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
# ...

# %%
import os
import torch
import nest_asyncio
import warnings
from peft import PeftModel
from fastapi import FastAPI
from pydantic import BaseModel
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig,T5ForConditionalGeneration, T5Tokenizer
from pyngrok import ngrok, conf
import uvicorn
import re
os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"
warnings.filterwarnings("ignore", message="Found missing adapter keys")

# %% [markdown]
# # QA MODEL

# %%
hf_token = "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"
ngrok_authtoken = "2sdLrLLjjeoQEJ4HXPQigirSz41_2kFXSH1pVc74aSH9fSCJk"


base_model_id = "mistralai/Mistral-7B-Instruct-v0.1"
adapter_id = "selsayed2003/mistral_qa_gen"

os.environ["PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION"] = "python"

tokenizer = AutoTokenizer.from_pretrained(base_model_id, token=hf_token)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

bnb_config = BitsAndBytesConfig(load_in_4bit=True)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_id,
    quantization_config=bnb_config,
    device_map="auto",
    offload_folder="offload",
    torch_dtype=torch.float16,
    token=hf_token
)


model = PeftModel.from_pretrained(base_model, adapter_id, token=hf_token, ignore_mismatched_sizes=True)
model.eval()

app = FastAPI()

class QARequest(BaseModel):
    context: str

def generate_qa(context: str, max_tokens: int = 128) -> str:
    prompt = f"Generate question and answer from this context:\n{context.strip()}"
    inputs = tokenizer(prompt, return_tensors="pt", truncation=True, padding=True).to(model.device)

    with torch.no_grad():
        outputs = model.generate(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            max_new_tokens=max_tokens,
            temperature=0.7,
            do_sample=True,
            top_k=50,
            top_p=0.95,
            eos_token_id=tokenizer.eos_token_id
        )

    result = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return result.replace(prompt, "").strip()

@app.post("/generate-qa")
async def qa_endpoint(req: QARequest):
    result = generate_qa(req.context)
    return {"qa": result}

nest_asyncio.apply()

conf.get_default().auth_token = ngrok_authtoken

public_url = ngrok.connect(8000)
print(f"🔗 Public URL: {public_url}")

uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# ERROR:asyncio:Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<Server.serve() done, defined at /usr/local/lib/python3.11/dist-packages/uvicorn/server.py:68> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/uvicorn/main.py", line 580, in run
#     server.run()
#   File "/usr/local/lib/python3.11/dist-packages/uvicorn/server.py", line 66, in run
#     return asyncio.run(self.serve(sockets=sockets))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nest_asyncio.py", line 30, in run
#     return loop.run_until_complete(task)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/nest_asyncio.py", line 92, in run_until_complete
#     self._run_once()
#   File "/usr/local/lib/python3.11/dist-packages/nest_asyncio.py", line 133, in _run_once
#     handle._run()
# ...

# %% [markdown]
# # SUMMARY MODEL

# %%
# !pip install fastapi uvicorn nest-asyncio pyngrok transformers torch --quiet

hf_token = None

repo_id = "SalmaSherif202200622/Summarization_NLP_model"

model = T5ForConditionalGeneration.from_pretrained(repo_id, use_auth_token=hf_token)
tokenizer = T5Tokenizer.from_pretrained(repo_id, use_auth_token=hf_token)

device = "cuda:0" if torch.cuda.is_available() else "cpu"
model.to(device)
model.eval()

app = FastAPI()

class TextRequest(BaseModel):
    text: str

def summarize_text(text, max_length=128, num_beams=4):
    inputs = tokenizer(
        text,
        max_length=512,
        padding="max_length",
        truncation=True,
        return_tensors="pt"
    ).to(device)
    with torch.no_grad():
        outputs = model.generate(
            input_ids=inputs["input_ids"],
            attention_mask=inputs["attention_mask"],
            max_length=max_length,
            num_beams=num_beams,
            early_stopping=True
        )
    summary = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return summary

@app.post("/summarize")
async def summarize(request: TextRequest):
    text = request.text
    summary = summarize_text(text)
    return {"summary": summary}

nest_asyncio.apply()

public_url = ngrok.connect(8000)
print(f"Public URL: {public_url}")

uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.48k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.35k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]
# ...

# %% [markdown]
# # CONTEXT ANSWER MODEL

# %%
from huggingface_hub import login
login(token = "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")

# %%
base_model_id = "mistralai/Mistral-7B-Instruct-v0.1"
adapter_model_id ="Dohahemdann/mistral_qa_answerNEWepochs"

# !nohup vllm serve "{base_model_id}" --dtype=half --gpu-memory-utilization 0.95 --load-format bitsandbytes --max_lora_rank 64 --enable-lora --lora-modules data-lora="{adapter_model_id}" --quantization bitsandbytes &
# Out:
# nohup: appending output to 'nohup.out'
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public vLLM Endpoint: NgrokTunnel: "https://7d48-34-124-139-137.ngrok-free.app" -> "http://localhost:8000"

# %%
# !tail -n 30 nohup.out
# Out:
# Fetching 8 files: 100%|██████████| 8/8 [00:01<00:00,  5.63it/s]
# INFO 05-11 00:02:02 [serving_models.py:185] Loaded new LoRA adapter: name 'data-lora', path 'Dohahemdann/mistral_qa_answerNEWepochs'
# INFO 05-11 00:02:02 [api_server.py:1090] Starting vLLM API server on http://0.0.0.0:8000
# INFO 05-11 00:02:02 [launcher.py:28] Available routes are:
# INFO 05-11 00:02:02 [launcher.py:36] Route: /openapi.json, Methods: HEAD, GET
# INFO 05-11 00:02:02 [launcher.py:36] Route: /docs, Methods: HEAD, GET
# INFO 05-11 00:02:02 [launcher.py:36] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# INFO 05-11 00:02:02 [launcher.py:36] Route: /redoc, Methods: HEAD, GET
# INFO 05-11 00:02:02 [launcher.py:36] Route: /health, Methods: GET
# INFO 05-11 00:02:02 [launcher.py:36] Route: /load, Methods: GET
# INFO 05-11 00:02:02 [launcher.py:36] Route: /ping, Methods: GET, POST
# INFO 05-11 00:02:02 [launcher.py:36] Route: /tokenize, Methods: POST
# ...

# %%
# !ngrok authtoken 2sdLrLLjjeoQEJ4HXPQigirSz41_2kFXSH1pVc74aSH9fSCJk

import uvicorn
import nest_asyncio
from pyngrok import ngrok
ngrok.kill()

# Start a new tunnel
public_url = ngrok.connect(8000)
print("Public vLLM Endpoint:", public_url)
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public vLLM Endpoint: NgrokTunnel: "https://419e-34-124-139-137.ngrok-free.app" -> "http://localhost:8000"
